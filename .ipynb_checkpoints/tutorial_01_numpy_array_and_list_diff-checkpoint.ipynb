# %% [markdown]
# # Tutorial 1:

# %% [markdown]
# **IMPORTING NUMPY**

# %%
import numpy as np

# %% [markdown]
# **NUMPY ARRAY**

# %%
array_1 = np.array([1,2,3,4])
print(array_1)
# Out:
# [1 2 3 4]

# %% [markdown]
# **PYTHON LIST**

# %%
list_1 = [1,2,3,4]
print(list_1)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# **TYPES OF NUMPY ARRAY AND PYTHON LIST**

# %%
print(type(array_1))
print(type(list_1))
# Out:
# <class 'numpy.ndarray'>
# <class 'list'>
